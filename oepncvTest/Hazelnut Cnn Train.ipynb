# %%
#버전확인
# !nvcc --version 쿠다
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Fri_Dec_17_18:28:54_Pacific_Standard_Time_2021
# Cuda compilation tools, release 11.6, V11.6.55
# Build cuda_11.6.r11.6/compiler.30794723_0

# %%
#쿠다버전맞게설치
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in c:\users\an\anaconda3\lib\site-packages (1.10.2)
# Requirement already satisfied: torchvision in c:\users\an\anaconda3\lib\site-packages (0.11.3)
# Requirement already satisfied: torchaudio in c:\users\an\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: dataclasses in c:\users\an\anaconda3\lib\site-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in c:\users\an\anaconda3\lib\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in c:\users\an\anaconda3\lib\site-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\an\anaconda3\lib\site-packages (from torchvision) (8.4.0)

# %%
#파이토치 쿠다버전확인
import torch
print("CUDA 사용 가능:", torch.cuda.is_available())
print("CUDA 버전:", torch.version.cuda)
print("GPU 이름:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "GPU 없음")
# Out:
# CUDA 사용 가능: False
# CUDA 버전: None
# GPU 이름: GPU 없음

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import os

# 하이퍼파라미터
batch_size = 32
epochs = 30
lr = 0.001
num_classes = 5
image_size = 224
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 경로 설정
train_dir = "hazelnut/train"

# 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

# 데이터셋 로드
train_dataset = ImageFolder(train_dir, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# 간단한 CNN 모델 정의
model = nn.Sequential(
    nn.Conv2d(3, 16, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(16, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Flatten(),
    nn.Linear(32 * 56 * 56, 128),
    nn.ReLU(),
    nn.Linear(128, num_classes)
).to(device)

# 손실 함수와 옵티마이저
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# 학습 루프
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"[Epoch {epoch+1}/{epochs}] Loss: {running_loss / len(train_loader):.4f}")

# ONNX로 모델 저장
dummy_input = torch.randn(1, 3, image_size, image_size).to(device)
torch.onnx.export(model, dummy_input, "hazel_model.onnx",
                  input_names=['input'], output_names=['output'],
                  dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}})

print("✅ ONNX 모델 저장 완료: hazel_model.onnx")
# Out:
# [Epoch 1/30] Loss: 2.1626
# [Epoch 2/30] Loss: 1.7312
# [Epoch 3/30] Loss: 1.5541
# [Epoch 4/30] Loss: 1.5329
# [Epoch 5/30] Loss: 1.4922
# [Epoch 6/30] Loss: 1.5015
# [Epoch 7/30] Loss: 1.4190
# [Epoch 8/30] Loss: 1.3393
# [Epoch 9/30] Loss: 1.2411
# [Epoch 10/30] Loss: 1.0893
# [Epoch 11/30] Loss: 1.1639
# [Epoch 12/30] Loss: 0.9954
# [Epoch 13/30] Loss: 0.9132
# [Epoch 14/30] Loss: 0.8854
# [Epoch 15/30] Loss: 0.7562
# [Epoch 16/30] Loss: 0.6999
# [Epoch 17/30] Loss: 0.6221
# [Epoch 18/30] Loss: 0.5377
# [Epoch 19/30] Loss: 0.5350
# [Epoch 20/30] Loss: 0.5271
# [Epoch 21/30] Loss: 0.4357
# [Epoch 22/30] Loss: 0.3977
# [Epoch 23/30] Loss: 0.3086
# [Epoch 24/30] Loss: 0.3469
# [Epoch 25/30] Loss: 0.3349
# [Epoch 26/30] Loss: 0.3268
# [Epoch 27/30] Loss: 0.2329
# [Epoch 28/30] Loss: 0.3436
# [Epoch 29/30] Loss: 0.2250
# [Epoch 30/30] Loss: 0.2042
# ✅ ONNX 모델 저장 완료: hazel_model.onnx

# %%
print(train_dataset.class_to_idx)
# Out:
# {'crack': 0, 'cut': 1, 'good': 2, 'hole': 3, 'print': 4}

# %% [markdown]
# ## Epoch 10으로하니까 25퍼 나옴
# ## 30으로 변경해서 사용 5퍼 나옴

# %%
import cv2
import numpy as np
from glob import glob
import os

# 클래스 인덱스 기준 (PyTorch에서 학습한 기준)
class_names = ['crack', 'cut', 'good', 'hole', 'print']
GOOD_INDEX = 2  # good 클래스 인덱스

# 모델 불러오기
net = cv2.dnn.readNetFromONNX("hazel_model.onnx")

# 테스트 이미지 경로 (good 클래스만)
image_paths = glob("hazelnut/test/good/*.png")  # .jpg면 바꿔줘

correct = 0
total = 0
pred_counts = [0] * 5  # 클래스별 예측 개수 기록

for path in image_paths:
    img = cv2.imread(path)
    if img is None:
        print(f"이미지 로드 실패: {path}")
        continue

    blob = cv2.dnn.blobFromImage(img, 1.0/255.0, (224, 224), swapRB=True)
    net.setInput(blob)
    output = net.forward()

    pred = np.argmax(output)
    pred_counts[pred] += 1
    total += 1

    print(f"[{total}] {os.path.basename(path)} → 예측: {class_names[pred]} ({pred})")

    if pred == GOOD_INDEX:
        correct += 1

# 정확도 출력
accuracy = correct / total * 100 if total > 0 else 0
print(f"\n✅ good 테스트 정확도: {accuracy:.2f}% ({correct}/{total})")

# 예측 분포 출력
print("\n📊 클래스별 예측 개수:")
for i, count in enumerate(pred_counts):
    print(f"{class_names[i]} ({i}): {count}")
# Out:
# [1] 000.png → 예측: print (4)
# [2] 001.png → 예측: print (4)
# [3] 002.png → 예측: print (4)
# [4] 003.png → 예측: print (4)
# [5] 004.png → 예측: print (4)
# [6] 005.png → 예측: hole (3)
# [7] 006.png → 예측: print (4)
# [8] 007.png → 예측: print (4)
# [9] 008.png → 예측: hole (3)
# [10] 009.png → 예측: print (4)
# [11] 010.png → 예측: hole (3)
# [12] 011.png → 예측: hole (3)
# [13] 012.png → 예측: print (4)
# [14] 013.png → 예측: hole (3)
# [15] 014.png → 예측: hole (3)
# [16] 015.png → 예측: hole (3)
# [17] 016.png → 예측: hole (3)
# [18] 017.png → 예측: print (4)
# [19] 018.png → 예측: print (4)
# [20] 019.png → 예측: print (4)
# [21] 020.png → 예측: print (4)
# [22] 021.png → 예측: hole (3)
# [23] 022.png → 예측: hole (3)
# [24] 023.png → 예측: print (4)
# [25] 024.png → 예측: print (4)
# [26] 025.png → 예측: print (4)
# [27] 026.png → 예측: hole (3)
# [28] 027.png → 예측: hole (3)
# [29] 028.png → 예측: print (4)
# [30] 029.png → 예측: print (4)
# [31] 030.png → 예측: hole (3)
# [32] 031.png → 예측: hole (3)
# [33] 032.png → 예측: hole (3)
# [34] 033.png → 예측: hole (3)
# [35] 034.png → 예측: print (4)
# [36] 035.png → 예측: cut (1)
# [37] 036.png → 예측: hole (3)
# [38] 037.png → 예측: hole (3)
# [39] 038.png → 예측: print (4)
# [40] 039.png → 예측: print (4)
# [41] 040.png → 예측: print (4)
# [42] 041.png → 예측: print (4)
# [43] 042.png → 예측: print (4)
# [44] 043.png → 예측: print (4)
# [45] 044.png → 예측: print (4)
# [46] 045.png → 예측: print (4)
# [47] 046.png → 예측: print (4)
# [48] 047.png → 예측: print (4)
# [49] 048.png → 예측: print (4)
# [50] 049.png → 예측: print (4)
# [51] 050.png → 예측: print (4)
# [52] 051.png → 예측: print (4)
# [53] 052.png → 예측: print (4)
# [54] 053.png → 예측: print (4)
# [55] 054.png → 예측: print (4)
# [56] 055.png → 예측: print (4)
# [57] 056.png → 예측: print (4)
# [58] 057.png → 예측: print (4)
# [59] 058.png → 예측: print (4)
# [60] 059.png → 예측: print (4)
# [61] 060.png → 예측: print (4)
# [62] 061.png → 예측: print (4)
# [63] 062.png → 예측: print (4)
# [64] 063.png → 예측: print (4)
# [65] 064.png → 예측: print (4)
# [66] 065.png → 예측: print (4)
# [67] 066.png → 예측: print (4)
# [68] 067.png → 예측: print (4)
# [69] 068.png → 예측: print (4)
# [70] 069.png → 예측: print (4)
# [71] 070.png → 예측: print (4)
# [72] 071.png → 예측: print (4)
# [73] 072.png → 예측: print (4)
# [74] 073.png → 예측: print (4)
# [75] 074.png → 예측: print (4)
# [76] 075.png → 예측: print (4)
# [77] 076.png → 예측: print (4)
# [78] 077.png → 예측: print (4)
# [79] 078.png → 예측: print (4)
# [80] 079.png → 예측: print (4)
# [81] 080.png → 예측: print (4)
# [82] 081.png → 예측: print (4)
# [83] 082.png → 예측: print (4)
# [84] 083.png → 예측: print (4)
# [85] 084.png → 예측: print (4)
# [86] 085.png → 예측: print (4)
# [87] 086.png → 예측: print (4)
# [88] 087.png → 예측: print (4)
# [89] 088.png → 예측: print (4)
# [90] 089.png → 예측: print (4)
# [91] 090.png → 예측: print (4)
# [92] 091.png → 예측: print (4)
# [93] 092.png → 예측: print (4)
# [94] 093.png → 예측: print (4)
# [95] 094.png → 예측: print (4)
# [96] 095.png → 예측: print (4)
# [97] 096.png → 예측: print (4)
# [98] 097.png → 예측: print (4)
# [99] 098.png → 예측: print (4)
# [100] 099.png → 예측: print (4)
# [101] 100.png → 예측: print (4)
# [102] 101.png → 예측: print (4)
# [103] 102.png → 예측: print (4)
# [104] 103.png → 예측: print (4)
# [105] 104.png → 예측: print (4)
# [106] 105.png → 예측: print (4)
# [107] 106.png → 예측: print (4)
# [108] 107.png → 예측: print (4)
# [109] 108.png → 예측: print (4)
# [110] 109.png → 예측: print (4)
# [111] 110.png → 예측: print (4)
# [112] 111.png → 예측: print (4)
# [113] 112.png → 예측: print (4)
# [114] 113.png → 예측: print (4)
# [115] 114.png → 예측: print (4)
# [116] 115.png → 예측: print (4)
# [117] 116.png → 예측: print (4)
# [118] 117.png → 예측: print (4)
# [119] 118.png → 예측: print (4)
# [120] 119.png → 예측: print (4)
# [121] 120.png → 예측: print (4)
# [122] 121.png → 예측: print (4)
# [123] 122.png → 예측: print (4)
# [124] 123.png → 예측: print (4)
# [125] 124.png → 예측: print (4)
# [126] 125.png → 예측: print (4)
# [127] 126.png → 예측: print (4)
# [128] 127.png → 예측: print (4)
# [129] 128.png → 예측: print (4)
# [130] 129.png → 예측: print (4)
# [131] 130.png → 예측: print (4)
# [132] 131.png → 예측: print (4)
# [133] 132.png → 예측: print (4)
# [134] 133.png → 예측: print (4)
# [135] 134.png → 예측: print (4)
# [136] 135.png → 예측: print (4)
# [137] 136.png → 예측: print (4)
# [138] 137.png → 예측: print (4)
# [139] 138.png → 예측: print (4)
# [140] 139.png → 예측: print (4)
# [141] 140.png → 예측: print (4)
# [142] 141.png → 예측: print (4)
# [143] 142.png → 예측: print (4)
# [144] 143.png → 예측: print (4)
# [145] 144.png → 예측: print (4)
# [146] 145.png → 예측: print (4)
# [147] 146.png → 예측: print (4)
# [148] 147.png → 예측: print (4)
# [149] 148.png → 예측: print (4)
# [150] 149.png → 예측: print (4)
# [151] 150.png → 예측: print (4)
# [152] 151.png → 예측: print (4)
# [153] 152.png → 예측: print (4)
# [154] 153.png → 예측: print (4)
# [155] 154.png → 예측: print (4)
# [156] 155.png → 예측: hole (3)
# [157] 156.png → 예측: hole (3)
# [158] 157.png → 예측: print (4)
# [159] 158.png → 예측: print (4)
# [160] 159.png → 예측: print (4)
# [161] 160.png → 예측: print (4)
# [162] 161.png → 예측: print (4)
# [163] 162.png → 예측: print (4)
# [164] 163.png → 예측: print (4)
# [165] 164.png → 예측: print (4)
# [166] 165.png → 예측: print (4)
# [167] 166.png → 예측: print (4)
# [168] 167.png → 예측: print (4)
# [169] 168.png → 예측: print (4)
# [170] 169.png → 예측: print (4)
# [171] 170.png → 예측: print (4)
# [172] 171.png → 예측: print (4)
# [173] 172.png → 예측: print (4)
# [174] 173.png → 예측: print (4)
# [175] 174.png → 예측: print (4)
# [176] 175.png → 예측: print (4)
# [177] 176.png → 예측: print (4)
# [178] 177.png → 예측: print (4)
# [179] 178.png → 예측: print (4)
# [180] 179.png → 예측: print (4)
# [181] 180.png → 예측: print (4)
# [182] 181.png → 예측: print (4)
# [183] 182.png → 예측: print (4)
# [184] 183.png → 예측: print (4)
# [185] 184.png → 예측: print (4)
# [186] 185.png → 예측: print (4)
# [187] 186.png → 예측: print (4)
# [188] 187.png → 예측: print (4)
# [189] 188.png → 예측: print (4)
# [190] 189.png → 예측: print (4)
# [191] 190.png → 예측: print (4)
# [192] 191.png → 예측: print (4)
# [193] 192.png → 예측: print (4)
# [194] 193.png → 예측: print (4)
# [195] 194.png → 예측: print (4)
# [196] 195.png → 예측: print (4)
# [197] 196.png → 예측: print (4)
# [198] 197.png → 예측: print (4)
# [199] 198.png → 예측: print (4)
# [200] 199.png → 예측: print (4)
# [201] 200.png → 예측: print (4)
# [202] 201.png → 예측: print (4)
# [203] 202.png → 예측: print (4)
# [204] 203.png → 예측: print (4)
# [205] 204.png → 예측: print (4)
# [206] 205.png → 예측: print (4)
# [207] 206.png → 예측: print (4)
# [208] 207.png → 예측: print (4)
# [209] 208.png → 예측: print (4)
# [210] 209.png → 예측: print (4)
# [211] 210.png → 예측: print (4)
# [212] 211.png → 예측: print (4)
# [213] 212.png → 예측: print (4)
# [214] 213.png → 예측: print (4)
# [215] 214.png → 예측: print (4)
# [216] 215.png → 예측: print (4)
# [217] 216.png → 예측: print (4)
# [218] 217.png → 예측: hole (3)
# [219] 218.png → 예측: print (4)
# [220] 219.png → 예측: print (4)
# [221] 220.png → 예측: print (4)
# [222] 221.png → 예측: print (4)
# [223] 222.png → 예측: hole (3)
# [224] 223.png → 예측: print (4)
# [225] 224.png → 예측: hole (3)
# [226] 225.png → 예측: print (4)
# [227] 226.png → 예측: crack (0)
# [228] 227.png → 예측: print (4)
# [229] 228.png → 예측: print (4)
# [230] 229.png → 예측: print (4)
# [231] 230.png → 예측: print (4)
# [232] 231.png → 예측: print (4)
# [233] 232.png → 예측: print (4)
# [234] 233.png → 예측: print (4)
# [235] 234.png → 예측: print (4)
# [236] 235.png → 예측: print (4)
# [237] 236.png → 예측: print (4)
# [238] 237.png → 예측: print (4)
# [239] 238.png → 예측: print (4)
# [240] 239.png → 예측: print (4)
# [241] 240.png → 예측: print (4)
# [242] 241.png → 예측: print (4)
# [243] 242.png → 예측: print (4)
# [244] 243.png → 예측: print (4)
# [245] 244.png → 예측: print (4)
# [246] 245.png → 예측: hole (3)
# [247] 246.png → 예측: print (4)
# [248] 247.png → 예측: hole (3)
# [249] 248.png → 예측: hole (3)
# [250] 249.png → 예측: hole (3)
# [251] 250.png → 예측: print (4)
# [252] 251.png → 예측: print (4)
# [253] 252.png → 예측: print (4)
# [254] 253.png → 예측: print (4)
# [255] 254.png → 예측: hole (3)
# [256] 255.png → 예측: hole (3)
# [257] 256.png → 예측: hole (3)
# [258] 257.png → 예측: hole (3)
# [259] 258.png → 예측: hole (3)
# [260] 259.png → 예측: print (4)
# [261] 260.png → 예측: print (4)
# [262] 261.png → 예측: print (4)
# [263] 262.png → 예측: print (4)
# [264] 263.png → 예측: print (4)
# [265] 264.png → 예측: hole (3)
# [266] 265.png → 예측: crack (0)
# [267] 266.png → 예측: crack (0)
# [268] 267.png → 예측: hole (3)
# [269] 268.png → 예측: cut (1)
# [270] 269.png → 예측: hole (3)
# [271] 270.png → 예측: print (4)
# [272] 271.png → 예측: hole (3)
# [273] 272.png → 예측: hole (3)
# [274] 273.png → 예측: print (4)
# [275] 274.png → 예측: print (4)
# [276] 275.png → 예측: print (4)
# [277] 276.png → 예측: print (4)
# [278] 277.png → 예측: print (4)
# [279] 278.png → 예측: print (4)
# [280] 279.png → 예측: print (4)
# [281] 280.png → 예측: print (4)
# [282] 281.png → 예측: print (4)
# [283] 282.png → 예측: print (4)
# [284] 283.png → 예측: print (4)
# [285] 284.png → 예측: print (4)
# [286] 285.png → 예측: print (4)
# [287] 286.png → 예측: print (4)
# [288] 287.png → 예측: print (4)
# [289] 288.png → 예측: print (4)
# [290] 289.png → 예측: print (4)
# [291] 290.png → 예측: print (4)
# [292] 291.png → 예측: print (4)
# [293] 292.png → 예측: print (4)
# [294] 293.png → 예측: print (4)
# [295] 294.png → 예측: print (4)
# [296] 295.png → 예측: print (4)
# [297] 296.png → 예측: print (4)
# [298] 297.png → 예측: print (4)
# [299] 298.png → 예측: print (4)
# [300] 299.png → 예측: print (4)
# [301] 300.png → 예측: print (4)
# [302] 301.png → 예측: print (4)
# [303] 302.png → 예측: print (4)
# [304] 303.png → 예측: print (4)
# [305] 304.png → 예측: print (4)
# [306] 305.png → 예측: print (4)
# [307] 306.png → 예측: print (4)
# [308] 307.png → 예측: print (4)
# [309] 308.png → 예측: print (4)
# [310] 309.png → 예측: print (4)
# [311] 310.png → 예측: print (4)
# [312] 311.png → 예측: print (4)
# [313] 312.png → 예측: print (4)
# [314] 313.png → 예측: print (4)
# [315] 314.png → 예측: print (4)
# [316] 315.png → 예측: print (4)
# [317] 316.png → 예측: print (4)
# [318] 317.png → 예측: print (4)
# [319] 318.png → 예측: good (2)
# [320] 319.png → 예측: good (2)
# [321] 320.png → 예측: good (2)
# [322] 321.png → 예측: good (2)
# [323] 322.png → 예측: good (2)
# [324] 323.png → 예측: print (4)
# [325] 324.png → 예측: cut (1)
# [326] 325.png → 예측: good (2)
# [327] 326.png → 예측: good (2)
# [328] 327.png → 예측: good (2)
# [329] 328.png → 예측: good (2)
# [330] 329.png → 예측: good (2)
# [331] 330.png → 예측: good (2)
# [332] 331.png → 예측: cut (1)
# [333] 332.png → 예측: good (2)
# [334] 333.png → 예측: good (2)
# [335] 334.png → 예측: print (4)
# [336] 335.png → 예측: print (4)
# [337] 336.png → 예측: good (2)
# [338] 337.png → 예측: good (2)
# [339] 338.png → 예측: good (2)
# [340] 339.png → 예측: good (2)
# [341] 340.png → 예측: good (2)
# [342] 341.png → 예측: good (2)
# [343] 342.png → 예측: print (4)
# [344] 343.png → 예측: print (4)
# [345] 344.png → 예측: print (4)
# [346] 345.png → 예측: hole (3)
# [347] 346.png → 예측: print (4)
# [348] 347.png → 예측: hole (3)
# [349] 348.png → 예측: print (4)
# [350] 349.png → 예측: print (4)
# [351] 350.png → 예측: print (4)
# [352] 351.png → 예측: print (4)
# [353] 352.png → 예측: print (4)
# [354] 353.png → 예측: print (4)
# [355] 354.png → 예측: print (4)
# [356] 355.png → 예측: print (4)
# [357] 356.png → 예측: print (4)
# [358] 357.png → 예측: print (4)
# [359] 358.png → 예측: print (4)
# [360] 359.png → 예측: hole (3)
# [361] 360.png → 예측: print (4)
# [362] 361.png → 예측: print (4)
# [363] 362.png → 예측: print (4)
# [364] 363.png → 예측: hole (3)
# [365] 364.png → 예측: print (4)
# [366] 365.png → 예측: hole (3)
# [367] 366.png → 예측: print (4)
# [368] 367.png → 예측: hole (3)
# [369] 368.png → 예측: print (4)
# [370] 369.png → 예측: hole (3)
# [371] 370.png → 예측: print (4)
# [372] 371.png → 예측: print (4)
# [373] 372.png → 예측: print (4)
# [374] 373.png → 예측: print (4)
# [375] 374.png → 예측: print (4)
# [376] 375.png → 예측: print (4)
# [377] 376.png → 예측: hole (3)
# [378] 377.png → 예측: print (4)
# [379] 378.png → 예측: print (4)
# [380] 379.png → 예측: print (4)
# [381] 380.png → 예측: hole (3)
# [382] 381.png → 예측: hole (3)
# [383] 382.png → 예측: print (4)
# [384] 383.png → 예측: print (4)
# [385] 384.png → 예측: hole (3)
# [386] 385.png → 예측: print (4)
# [387] 386.png → 예측: print (4)
# [388] 387.png → 예측: hole (3)
# [389] 388.png → 예측: hole (3)
# [390] 389.png → 예측: hole (3)
# [391] 390.png → 예측: print (4)
#
# ✅ good 테스트 정확도: 4.86% (19/391)
#
# 📊 클래스별 예측 개수:
# crack (0): 3
# cut (1): 4
# good (2): 19
# hole (3): 51
# print (4): 314

# %% [markdown]
# # ResNet18 기반 분류 모델 전체 코드 (PyTorch)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import os

# 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 하이퍼파라미터
num_classes = 5
batch_size = 32
epochs = 10
lr = 0.001

# 경로
train_dir = "hazelnut/train"

# 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# 데이터셋 및 데이터로더
train_dataset = ImageFolder(train_dir, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# 모델 정의 (ResNet18 사전학습 모델 사용)
model = resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# 손실 함수와 옵티마이저
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# 학습 루프
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    acc = correct / total * 100
    print(f"[Epoch {epoch+1}/{epochs}] Loss: {running_loss/len(train_loader):.4f} | Accuracy: {acc:.2f}%")

# ONNX로 저장
dummy_input = torch.randn(1, 3, 224, 224).to(device)
torch.onnx.export(model, dummy_input, "hazel_model.onnx",
                  input_names=["input"], output_names=["output"],
                  dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}})

print("✅ ONNX 모델 저장 완료: hazel_model.onnx")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\AN/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# [Epoch 1/10] Loss: 1.1120 | Accuracy: 48.18%
# [Epoch 2/10] Loss: 0.3878 | Accuracy: 87.27%
# [Epoch 3/10] Loss: 0.3741 | Accuracy: 90.91%
# [Epoch 4/10] Loss: 0.2438 | Accuracy: 91.82%
# [Epoch 5/10] Loss: 0.0596 | Accuracy: 97.27%
# [Epoch 6/10] Loss: 0.0427 | Accuracy: 99.09%
# [Epoch 7/10] Loss: 0.0187 | Accuracy: 100.00%
# [Epoch 8/10] Loss: 0.0076 | Accuracy: 100.00%
# [Epoch 9/10] Loss: 0.0080 | Accuracy: 100.00%
# [Epoch 10/10] Loss: 0.1897 | Accuracy: 98.18%
# ✅ ONNX 모델 저장 완료: hazel_model.onnx

# %% [markdown]
# # ResNet18으로 바꾸고 정확도 100퍼
